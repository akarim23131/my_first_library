# %%
#| hide
from my_first_library.core import *

# %% [markdown]
# # my_first_library
#
# > This is my first test library creation repo

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install my_first_library in Development mode

# %% [markdown]
# ```sh
# # make sure my_first_library package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to my_first_library
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/akarim23131/my_first_library.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c akarim23131 my_first_library
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install my_first_library
# ```
#
#
# [repo]: https://github.com/akarim23131/my_first_library
# [docs]: https://akarim23131.github.io/my_first_library/
# [pypi]: https://pypi.org/project/my_first_library/
# [conda]: https://anaconda.org/akarim23131/my_first_library

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/akarim23131/my_first_library
# [docs]: https://akarim23131.github.io/my_first_library/
# [pypi]: https://pypi.org/project/my_first_library/
# [conda]: https://anaconda.org/akarim23131/my_first_library

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
